# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df=pd.read_csv("homeprices.csv")
print(df)
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
print(df.shape)
df.head()
# Out:
# (5, 2)
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
# %matplotlib inline
plt.xlabel('area(sqr ft)')
plt.ylabel('price(US$)')
plt.scatter(df.area,df.price, color='red', marker='+')

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['area']],df.price)
# Out:
# LinearRegression()

# %%
reg.predict([[3300]])
# Out:
# /home/shital/.local/lib/python3.8/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([628715.75342466])

# %%
reg.coef_
# Out:
# array([135.78767123])

# %%
reg.intercept_
# Out:
# 180616.43835616432

# %%
# y=m*x+b
135.78767123*3300+180616.43835616432
# Out:
# 628715.7534151643

# %%
data = pd.read_csv('area.csv')
print(data.shape)
data.head()
# Out:
# (9, 1)
#    area
# 0  1000
# 1  1500
# 2  2000
# 3  2500
# 4  3000

# %%
reg.predict(data)
# Out:
# array([316404.10958904, 384297.94520548, 452191.78082192, 520085.61643836,
#        587979.45205479, 655873.28767123, 723767.12328767, 791660.95890411,
#        859554.79452055])

# %%
p = reg.predict(data)
data['prices'] = p

# %%
data
# Out:
#    area         prices
# 0  1000  316404.109589
# 1  1500  384297.945205
# 2  2000  452191.780822
# 3  2500  520085.616438
# 4  3000  587979.452055
# 5  3500  655873.287671
# 6  4000  723767.123288
# 7  4500  791660.958904
# 8  5000  859554.794521

# %%
data.to_csv('prediction.csv')

# %%
# %matplotlib inline
plt.xlabel('area', fontsize=20)
plt.ylabel('price', fontsize=20)
plt.scatter(data.area,data.prices,color='red',marker='+')
plt.plot(data.area,reg.predict(data[['area']]),color='blue')
